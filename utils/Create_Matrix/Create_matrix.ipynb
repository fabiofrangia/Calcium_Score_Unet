# %%
from create_overlap_matrix import OverlapMatrix
import numpy as np
from matplotlib import pyplot as plt
import SimpleITK as sitk

# %%
matrix = OverlapMatrix(75,85,80,45)
overlap_matrix = matrix.create_matrix()

# %%
img = sitk.GetImageFromArray(overlap_matrix)

# %%
sitk.WriteImage(img, 'image.nii.gz')

# %%
plt.figure(figsize=(10,10))
plt.imshow(overlap_matrix[:,:,10],cmap='gray')
